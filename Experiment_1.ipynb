# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhankit-R/Python-for-Data-Science/blob/main/Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World !")
# Out:
# Hello World !

# %%
print("Namaste Python")
# Out:
# Namaste Python

# %%
a = 5; a = "HELLO"
print(a)
# Out:
# HELLO

# %%
num = 5
square = num ** 2
print(f"The square of {num} is {square}") # Output: 25
# Out:
# The square of 5 is 25

# %%
num = 5
square = num * num
print(f"The square of {num} is {square}") # Output: 25
# Out:
# The square of 5 is 25

# %%
num = 5
square = pow(num, 2)
print(f"The square of {num} is {square}") # Output: 25
# Out:
# The square of 5 is 25

# %%
# Get input from user
num = float(input("Enter a number: "))
# Calculate square
square = num ** 2
# Display result
print(f"The square of {num} is {square}")
# Out:
# Enter a number: 6
# The square of 6.0 is 36.0
